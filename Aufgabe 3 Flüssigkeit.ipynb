# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def conv(x):
    return x.replace(",", ".").encode()
# %matplotlib inline

# %%
_450micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/450micro_std.CSV")), delimiter =";")
_400micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/400micro_std.CSV")), delimiter =";")
_350micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/350micro_std.CSV")), delimiter =";")
#300 fehlt 
_250micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/250micro_std.CSV")), delimiter =";")
_200micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/200micro_std.CSV")), delimiter =";")
_175micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/175micor_std.CSV")), delimiter =";")
_150micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/150micro_std.CSV")), delimiter =";")
_125micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/125micro_std.CSV")), delimiter =";")
_100micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/100micro_std.CSV")), delimiter =";")
_80micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/80micro_std.CSV")), delimiter =";")
_60micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/60micro_std.CSV")), delimiter =";")
_40micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/40micro_std.CSV")), delimiter =";")
_20micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/20micro_std.CSV")), delimiter =";")
_10micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/10micro_std.CSV")), delimiter =";")
_5micro_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/5micro_std.CSV")), delimiter =";")

_450iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso450_std.CSV")), delimiter =";")
_400iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso400_std.CSV")), delimiter =";")
_350iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso350_std.CSV")), delimiter =";")
#300 fehlt 
_250iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso250_std.CSV")), delimiter =";")
_200iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso200_std.CSV")), delimiter =";")
_175iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso175_std.CSV")), delimiter =";")
_150iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso150_std.CSV")), delimiter =";")
_125iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso125_std.CSV")), delimiter =";")
_100iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso100_std.CSV")), delimiter =";")
_80iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso80_std.CSV")), delimiter =";")
_60iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso60_std.CSV")), delimiter =";")
_40iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso40_std.CSV")), delimiter =";")
_20iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso20_std.CSV")), delimiter =";")
_10iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso10_std.CSV")), delimiter =";")
_5iso_std = np.genfromtxt((conv(x) for x in open("Aufgabe 3 Flüssigkeit/Isopropanol/iso5_std.CSV")), delimiter =";")

# %%
#cal all without noises
_450won = _450micro_std[:,1]- _450iso_std[:,1]
_400won = _400micro_std[:,1]- _400iso_std[:,1] 
_350won = _350micro_std[:,1]- _350iso_std[:,1] 
_250won = _250micro_std[:,1]- _250iso_std[:,1] 
_200won = _200micro_std[:,1]- _200iso_std[:,1] 
_175won = _175micro_std[:,1]- _175iso_std[:,1] 
_150won = _150micro_std[:,1]- _150iso_std[:,1]
_125won = _125micro_std[:,1]- _125iso_std[:,1] 
_100won = _100micro_std[:,1]- _100iso_std[:,1] 
_80won = _80micro_std[:,1]- _80iso_std[:,1] 
_60won = _60micro_std[:,1]- _60iso_std[:,1] 
_40won = _40micro_std[:,1]- _40iso_std[:,1] 
_20won = _20micro_std[:,1]- _20iso_std[:,1] 
_10won = _10micro_std[:,1]- _10iso_std[:,1] 
_5won = _5micro_std[:,1]- _5iso_std[:,1]

# %%
source = [_450won,_400won,_350won,_250won,_200won,_175won,_150won,_125won,_100won,_80won ,_60won ,_40won ,_20won ,_10won ,_5won]
sourceforprint = [450,400,350,250,200,175,150,125,100,80 ,60,40 ,20 ,10 ,5]
n = 1.37927

# %%
#plt.figure(figsize = [15,7])
#plt.axis([1000,1150,30,50])
plt.plot(_450micro_std[:,0],_450micro_std[:,1],label=r"450$\mathrm{\mu m}$")
#plt.plot(_400micro_std[:,0],_400micro_std[:,1],label=r"400$\mathrm{\mu m}$")
plt.plot(_350micro_std[:,0],_350micro_std[:,1],label=r"350$\mathrm{\mu m}$")
#plt.plot(_250micro_std[:,0],_250micro_std[:,1],label=r"250$\mathrm{\mu m}$")
#plt.plot(_200micro_std[:,0],_200micro_std[:,1],label=r"200$\mathrm{\mu m}$")
#plt.plot(_175micro_std[:,0],_175micro_std[:,1],label=r"175$\mathrm{\mu m}$")
#plt.plot(_150micro_std[:,0],_150micro_std[:,1],label=r"150$\mathrm{\mu m}$")
#plt.plot(_125micro_std[:,0],_125micro_std[:,1],label=r"125$\mathrm{\mu m}$")
#plt.plot(_100micro_std[:,0],_100micro_std[:,1],label=r"100$\mathrm{\mu m}$")
#plt.plot(_80micro_std[:,0],_80micro_std[:,1],label=r"80$\mathrm{\mu m}$")
#plt.scatter(_60micro_std[:,0],_60micro_std[:,1],label=r"60$\mathrm{\mu m}$")
#plt.plot(_40micro_std[:,0],_40micro_std[:,1],label=r"40$\mathrm{\mu m}$")
#plt.plot(_20micro_std[:,0],_20micro_std[:,1],label=r"20$\mathrm{\mu m}$")
#plt.plot(_10micro_std[:,0],_10micro_std[:,1],label=r"10$\mathrm{\mu m}$")
#plt.plot(_5micro_std[:,0],_5micro_std[:,1],label=r"5$\mathrm{\mu m}$")
plt.legend(loc = 0)
plt.ylabel("Extinktion")
plt.xlabel(r"Wellenvektor k$ [\mathrm{cm}^{-1}]$")
# Out:
# Text(0.5, 0, 'Wellenvektor k$ [\\mathrm{cm}^{-1}]$')

# %%
def gaus(x,a,x0,sigma):
        return a*np.exp(-(x-x0)**2/(2*sigma**2))

def calcthickness(mean,sigma,mean2,sigma2,array1,d1,d2,d3,d4,k,name,a=1):
    x1a = np.asarray(array1[d1:d2,0])
    x1e = np.asarray(array1[d3:d4,0])

    y1a = np.asarray(array1[d1:d2,1])
    y1e = np.asarray(array1[d3:d4,1])
    
    #fit gaussian
    popt1,pcov1 = curve_fit(gaus,x1a,y1a,p0=[a,mean,sigma])
    popt3,pcov3 = curve_fit(gaus,x1e,y1e,p0=[a,mean2,sigma2])

    plt.plot(x1a, gaus(x1a,*popt1), label='Gauß-Fit-Anfang 1')
    plt.plot(x1e, gaus(x1e,*popt3), label='Gauß-Fit-Ende 1')
    plt.scatter(array1[:,0],array1[:,1],c="lightskyblue",s=2,label="Daten")
    plt.legend(loc=2)
    plt.xlabel(r"Wellenvektor k $[\mathrm{cm^{-1}}]$")
    plt.ylabel("relative Intensität")
    plt.xlim(array1[d1,0]-30,array1[d4,0]+30)
    plt.ylim(array1[d1,1]-10,array1[d4,1]+10)
    plt.savefig("schichtdicke/del"+name+".pdf")

    n = 1.37927
    dk = popt3[1] - popt1[1]
    d = k/(2*n*dk)
    
    udk = np.sqrt((popt3[2])**2+(popt1[2])**2)
    ud = np.sqrt((udk*(-(k)/(2*n*dk**2)))**2)
    
    print("Schichtdicke= "+str(np.round(d*10000,2)),"; ","Messfehler= "+str(np.round(ud*10000,2)))
    print("Abstand der Maxima= "+str(np.round(dk,2)))

# %%
def cos(x,a,b,c,d):
    return a*np.cos(b*x+c)+d

def calcthickness_cosine(pop1,pop2,array1,mean,sigma,mean1,sigma1,k,name,a=1):
    x = array1[:,0]
    y = array1[:,1]
    
    left_index = np.abs(x - (mean-sigma)).argmin()
    right_index = np.abs(x - (mean+sigma)).argmin()
    
    x1a = np.asarray(x[left_index:right_index])
    y1a = np.asarray(y[left_index:right_index])
    
    left_index1 = np.abs(x - (mean1-sigma1)).argmin()
    right_index1 = np.abs(x - (mean1+sigma1)).argmin()
    
    x1e = np.asarray(x[left_index1:right_index1])
    y1e = np.asarray(y[left_index1:right_index1])
    
    #fit cosine
    popt1,pcov1 = curve_fit(cos,x1a,y1a,p0=[pop1])
    popt3,pcov3 = curve_fit(cos,x1e,y1e,p0=[pop2])
    
    leftpeakx = np.max(cos(x1a,*popt1))
    rightpeakx = np.max(cos(x1e,*popt3))
    
    leftpeak = np.interp(leftpeakx, y1a,x1a)
    rightpeak = np.interp(rightpeakx, y1e,x1e)
    
    #plt.plot(x1a, cos(x1a,*popt1), label='Cos-Fit 1')
    #plt.plot(x1e, cos(x1e,*popt3), label='Cos-Fit 2')
    #plt.scatter(array1[:,0],array1[:,1],c="lightskyblue",s=2,label="Daten")
    #plt.legend(loc=0)
    #plt.xlabel(r"Wellenvektor k $[\mathrm{cm^{-1}}]$")
    #plt.ylabel("Extinktion [%]")
    #plt.xlim(array1[left_index,0]-30,array1[right_index1,0]+30)
    #plt.ylim(array1[left_index,1]-10,array1[right_index1,1]+10)
    #plt.savefig("newplots/schichtdickenberechnung"+name+".pdf")

    
    dk = np.abs(leftpeak-rightpeak)
    d = k/(2*n*dk)
    #print(leftpeak,rightpeak)
    print("Schichtdicke= "+str(np.round(d*10000,2)),"Array: "+str(name))
    #print("Abstand der Maxima= "+str(np.round(dk,2)))

# %%
#plt.plot(_40micro_std[a:b,0],_5micro_std[a:b,1],label=r"350$\mathrm{\mu m}$")
#plt.axis([1020,1100,32,35])
calcthickness_cosine((10,1,0,2),(10,1,0,2),_450micro_std,821,3,923.5,4,9,"450")
calcthickness_cosine((10,1,0,2),(10,1,0,2),_400micro_std,2195,3,2208,4,1,"400")
calcthickness_cosine((10,1,0,2),(10,1,0,2),_350micro_std,2200.7,3,2215.5,4,1,"350")
calcthickness_cosine((10,1,0,2),(10,1,0,2),_250micro_std,1156.5,3.5,1177,4,1,"250")
calcthickness_cosine((20,1,0,2),(20,1,0,2),_200micro_std,1034,3,1059,4,1,"200")
calcthickness_cosine((20,1,0,2),(20,1,0,2),_175micro_std,955,3,984,4,1,"175")
calcthickness_cosine((20,1,0,2),(20,1,0,2),_150micro_std,945,5,978,5,1,"150")
calcthickness_cosine((20,1,0,2),(20,1,0,2),_125micro_std,965.5,5,1048.5,5,2,"125")
calcthickness_cosine((20,0.5,0,2),(20,1,0,2),_100micro_std,2454,6,2563,4,2,"100")
#calcthickness_cosine((10,0.3,0,2),(10,0.3,0,2),_80micro_std,2493.5,10,2563,4,1,"80") 
#calcthickness_cosine((10,0.3,0,2),(10,0.3,0,2),_60micro_std,2489,5,2578,10,1,"60")
#calcthickness_cosine((10,0.3,0,2),(10,0.3,0,2),_40micro_std,2475,3,2627,4,1,"40")
#keine Interferenz mehr deutlich zu erkennen und nicht mehr zu fitten
#calcthickness_cosine((10,1,0,2),(10,1,0,2),_20micro_std,2475,3,2627,4,1,"40")
#keine Interferenz mehr deutlich zu erkennen und nicht mehr zu fitten
# Out:
# Schichtdicke= 314.74 Array: 450
# Schichtdicke= 259.27 Array: 400
# Schichtdicke= 234.97 Array: 350
# Schichtdicke= 170.88 Array: 250
# Schichtdicke= 139.23 Array: 200
# Schichtdicke= 121.27 Array: 175
# Schichtdicke= 108.97 Array: 150
# Schichtdicke= 87.43 Array: 125
# Schichtdicke= 67.74 Array: 100

# %%
calcthickness_cosine((10,1,0,2),(10,1,0,2),_450micro_std,821,3,923.5,4,9,"450")
# Out:
# Schichtdicke= 314.74 Array: 450

# %%
dicke_not = np.array([450,400,350,250,200,175,150,125,100])
dicke_real = np.array([314.74,259.27,234.97,170.88,139.23,121.27,108.97,87.43,67.74])

def linear(x,m,b):
    return m*x+b

linpopt, lincov = curve_fit(linear,dicke_not,dicke_real,p0=[1,0])
linerror = np.sqrt(np.diag(lincov))
print(linerror)


plt.plot(dicke_not,linear(dicke_not,*linpopt),linestyle="--",label="Fit: "+str(np.round(linpopt[0],2))+"*x+ "+str(np.round(linpopt[1],2)))
plt.scatter(dicke_not, dicke_real,c="red",s=5,label="Daten")
plt.legend(loc=0)
plt.xlabel(r"Notierte Schichtdicke [$\mathrm{\mu m}$]")
plt.ylabel(r"Berechnete Schichtdicke [$\mathrm{\mu m}$]")
plt.title("Umrechnung in die realen Schichtdicken")
plt.savefig("newplots/linfitcalib.pdf")
# Out:
# [0.01788693 4.8666833 ]

# %%
old_thickness = [450,400,350,250,200,175,150,125,100,80,60,40,20,10,5]
newd=[]
#newderr = []
for i in range(len(old_thickness)):
    newd.append(linpopt[0]*old_thickness[i]+linpopt[1])
    #newderr.append(np.sqrt((err[0]*oldd[i])**2+(err[1])**2))
print(newd)
# Out:
# [304.20719999968196, 270.8730162159345, 237.5388324321871, 170.87046486469225, 137.5362810809448, 120.86918918907111, 104.2020972971974, 87.53500540532369, 70.86791351344996, 57.534239999951, 44.20056648645203, 30.86689297295306, 17.533219459454095, 10.866382702704609, 7.532964324329867]

# %% [raw]
# plt.figure(figsize = [15,7])
# plt.plot(np.arange(len(_400micro_std)),_450micro_std[:,1],label=r"450$\mathrm{\mu m}$")
# plt.legend(loc = "upper right")
# plt.ylabel("Intensität")
# plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")

# %%
plt.figure(figsize = [15,7])
plt.plot(_450iso_std[:,0],_450iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_400iso_std[:,0],_400iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_350iso_std[:,0],_350iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_250iso_std[:,0],_250iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_200iso_std[:,0],_200iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_175iso_std[:,0],_175iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_150iso_std[:,0],_150iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_125iso_std[:,0],_125iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_100iso_std[:,0],_100iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_80iso_std[:,0],_80iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_60iso_std[:,0],_60iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_40iso_std[:,0],_40iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_20iso_std[:,0],_20iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_10iso_std[:,0],_10iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_5iso_std[:,1],label=r"450$\mathrm{\mu m}$")
plt.legend(loc = "upper right")
plt.ylabel("Extinktion")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
# Out:
# Text(0.5, 0, 'Wellenvektor k$[\\mathrm{cm}^{-1}]$')

# %%
plt.plot(_5iso_std[:,0],_5won,label=r"450$\mathrm{\mu m}$")
#plt.plot(_5iso_std[:,0],_10won,label=r"450$\mathrm{\mu m}$")
#plt.plot(_5micro_std[:,0],_5iso_std[:,1],label="hintergrund")
plt.title(r"Extinktionsspektrum bei 5$\mathrm{\mu m}$-Schichtdicke")
plt.xlabel(r"Wellenvektor k $[\mathrm{cm}^{-1}]$")
plt.ylabel("Extinktion")
plt.grid(True)
plt.savefig("newplots/getavsorb.pdf")
#plt.axis([900,1000,0,35])
#plt.axis([1350,1400,-10,40])
#plt.axis([2950,3000,-10,45])
plt.axis([1400,1500,0,25])
# Out:
# (1400.0, 1500.0, 0.0, 25.0)

# %%
#plot all without noises
#plt.figure(figsize = [15,7])

plt.plot(_5iso_std[:,0],_450won,label=r"450$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_400won,label=r"400$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_350won,label=r"350$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_250won,label=r"250$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_200won,label=r"200$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_175won,label=r"175$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_150won,label=r"150$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_125won,label=r"125$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_100won,label=r"100$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_80won,label=r"80$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_60won,label=r"60$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_40won,label=r"40$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_20won,label=r"20$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_10won,label=r"10$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_5won,label=r"5$\mathrm{\mu m}$")
plt.legend(loc=0)

#plt.axis([900,1100,0,40])
#plt.axis([1465,1472,15,65])
#plt.axis([1750,1780,-10,60])
#plt.axis([2340,2420,0,50])
#plt.axis([2600,2720,-10,60])
#plt.axis([2900,3000,10,40])
plt.axis([3100,3600,0,40])
#plt.legend(loc = 2)
plt.ylabel("Extinktion [%]",fontsize=12)
plt.xlabel(r"Wellenvektor k $[\mathrm{cm}^{-1}]$",fontsize=12)
plt.grid(True)
plt.savefig("newplots/zoomohall.pdf")

# %%
#plt.plot(np.arange(len(_5won)),_5won,label=r"5$\mathrm{\mu m}$")
#plt.plot(np.arange(len(_5won)),_450won,label=r"5$\mathrm{\mu m}$")
#plt.axis([2490,2505,10,40])

# %%
def gaus(x,a,x0,sigma):
        return a*np.exp(-(x-x0)**2/(2*sigma**2))
    
def log(x,a,b):
    return a*np.log10(x)+b

def peakstuff(mean,sigma,x,y,a=1):
    extinction1,ext1error = [],[]
    
    left_index = np.abs(x - (mean-sigma)).argmin()
    right_index = np.abs(x - (mean+sigma)).argmin()
    
    x1a = np.asarray(x[left_index:right_index])
    y1a = np.asarray(y[left_index:right_index])

    #fit gaussian
    popt1,pcov1 = curve_fit(gaus,x1a,y1a,p0=[a,mean,sigma])

    a_height,c_width = popt1[1], np.abs(popt1[2])

    #peakindex = np.argmin(np.abs(_5iso_std[:,0]-a_height))

    p1a = np.argmin(np.abs(_5iso_std[:,0]-a_height+c_width))
    p1e = np.argmin(np.abs(_5iso_std[:,0]-a_height-c_width))

    for i in range(3,len(newd)-1):
        peakindex1 = np.interp(a_height,x,source[i])
        extinction1.append(peakindex1)
        ext1error.append(np.max([source[i][p1a:p1e]])-np.min([source[i][p1a:p1e]]))
        plt.scatter(x,source[i],s=0.5,label=str(sourceforprint[i])+r"$\mathrm{\mu m}$")
        
    plt.plot(x1a, gaus(x1a,*popt1), label='Gauß-Fit',c="orangered",linewidth=3)
    plt.plot([a_height,a_height],[np.interp(a_height,x,source[13]),np.interp(a_height,x,source[3])],linestyle="--",c="grey",label="Interpol. Max")
    plt.legend(loc=1)
    #plt.scatter(x,y,c="lightblue",s=2)
    plt.xlabel(r"Wellenvektor k $[\mathrm{cm^{-1}}]$",fontsize=12)
    plt.ylabel("Extinktion [%]",fontsize=12)
    plt.title(r"Extinktion bei k $\approx$"+str(np.round(popt1[1],2))+ "$\mathrm{cm^{-1}}$")
    plt.xlim(x[left_index]-50,x[right_index]+50)
    plt.ylim(y[left_index]-55,y[right_index]+3)
    plt.savefig("newplots/interpolext2nd.pdf")
    plt.show()
    
    poptlog, _ = curve_fit(log,newd[3:len(newd)-1],extinction1,sigma=ext1error)
    
    plt.plot(newd[3:len(newd)-1],log(newd[3:len(newd)-1],*poptlog),label="log10 Fit")
    #plt.plot(newd[3:len(newd)], extinction1,label="Daten")
    plt.errorbar(newd[3:len(newd)-1], extinction1,fmt='o',yerr= ext1error,markersize=2,capsize =2,label="Daten")
    plt.xlabel(r"Schichtdicke $[\mathrm{\mu m}]$", fontsize=12)
    plt.ylabel(r"Extinktion [%]",fontsize=12)
    plt.legend(loc=0)
    plt.savefig("newplots/extinction2nd.pdf")
    plt.show()

# %%
#peakstuff(1765.2,2,_450micro_std[:,0],_250won)

# %%
#peakstuff(2658,10,_5micro_std[:,0],_150won)

# %%
#peakstuff(2349,2,_5micro_std[:,0],_250won)

# %%
peakstuff(2522.5,10,_5micro_std[:,0],_250won)

# %%
#print(extinction1, extinction2)

# %%
#plot all without noises
#plt.figure(figsize = [15,7])

plt.plot(_5iso_std[:,0],_450won[:,],label=r"450$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_400won,label=r"400$\mathrm{\mu m}$")
plt.plot(_5iso_std[:,0],_350won,label=r"350$\mathrm{\mu m}$")
plt.scatter(_5iso_std[:,0],_250won,label=r"250$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_200won,label=r"200$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_175won,label=r"175$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_150won,label=r"150$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_125won,label=r"125$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_100won,label=r"100$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_80won,label=r"80$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_60won,label=r"60$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_40won,label=r"40$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_20won,label=r"20$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_10won,label=r"10$\mathrm{\mu m}$",s=2)
plt.scatter(_5iso_std[:,0],_5won,label=r"5$\mathrm{\mu m}$",s=2)



x1a = np.asarray(_5micro_std[:,0][2303:2325])
y1a = np.asarray(_5won[2303:2325])
    
#fit gaussian
popt1,pcov1 = curve_fit(gaus,x1a,y1a,p0=[1,1380,5])

#print(popt1[1],np.abs(popt1[2]))
    
#plt.plot(x1a, gaus(x1a,*popt1), linewidth=4,label='Gauß-Fit',c="green")
#plt.plot([_5micro_std[left_index],_5micro_std[right_index]],[10,65],'--',c="grey",linewidth=3,label=r"$\pm\sigma$")
#plt.plot([_5micro_std[left_index1],_5micro_std[right_index1]],[10,65],'--',c="grey",linewidth=3)
#plt.plot()

#plt.axis([900,1000,0,40])
#plt.axis([1350,1400,10,65])
#plt.axis([2900,3000,10,50])
#plt.axis([3100,3600,0,40])
plt.legend(loc = 0)
plt.ylabel("Extinktion")
plt.xlabel(r"Wellenvektor k $[\mathrm{cm}^{-1}]$")
plt.grid(True)
plt.savefig("newplots/zoomborder.pdf")

# %%
# pol1 = np.polyfit(np.log10(newd[3:len(newd)]), extinction1, 1)
# pol2 = np.polyfit(np.log10(newd[3:len(newd)]), extinction2, 1)

# x= newd[3:len(newd)]
# y1=[]
# y2=[]
# for i in range(0,len(x)):
#     y1.append(pol1[0]*newd[i]+pol1[1])
#     y2.append(pol2[0]*newd[i]+pol2[1])

# plt.plot(x,y1,c="green")
# plt.plot(newd[3:len(newd)], extinction1)
# plt.errorbar(newd[3:len(newd)], extinction1,fmt='o', xerr=newderr[3:len(newderr)],yerr= ext1error,markersize=2,capsize =2)
# plt.show()
# plt.plot(x,y2)
# plt.plot(newd[3:len(newd)], extinction2)
# plt.errorbar(newd[3:len(newd)], extinction2,fmt='o', xerr=newderr[3:len(newderr)],yerr= ext2error,markersize=2,capsize=2)
# plt.show()

# %%
# def log(a,b,x):
#         return a*np.log10(x)+b

# def logfit(a,b,x,y):
#     x1a = np.asarray(x)
#     y1a = np.asarray(y)
    
#     #fit gaussian
#     popt2,pcov2 = curve_fit(log,x1a,y1a,p0=[a,b])

#     print(popt2)
    
#     plt.plot(x1a, log(x1a,*popt2), label='Log-Fit')
#     plt.scatter(x,y,c="red",s=2)
#     plt.xlabel(r"Wellenvektor k $[\mathrm{cm^{-1}}]$")
#     plt.ylabel("Extinktion")
#     plt.show()

# %%
#logfit(5,10,newd[3:len(newd)],extinction1)
