# %%
import numpy as np
from pylab import * 
import matplotlib.pyplot as plt

# %%
def conv(x):
    return x.replace(",", ".").encode()
# %matplotlib inline

# %%
#import data
A05_S10_V4_Aphoch = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A0.5_S10_V4_Aphoch.CSV")), delimiter =";")
A05_S10_V4_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A0.5_S10_V4_Apm.CSV")), delimiter =";")
A4_S1_V4_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S1_V4_Apm.CSV")), delimiter =";")
A4_S10_V3_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V3_Apm.CSV")), delimiter =";")
A4_S10_V4_Apm_Boxcar = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V4_Apm_Boxcar.CSV")), delimiter =";")
A4_S10_V4_Apm_cosine = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V4_Apm_cosine.CSV")), delimiter =";")
A4_S10_V4_Apm_dreieck = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V4_Apm_dreieck.CSV")), delimiter =";")
A4_S10_V4_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V4_Apm.CSV")), delimiter =";")
A4_S10_V4_Apo = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V4_Apo.CSV")), delimiter =";")
A4_S10_V32_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S10_V32_Apm.CSV")), delimiter =";")
A4_S50_V4_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A4_S50_V4_Apm.CSV")), delimiter =";")
A32_S10_V4_Apm = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A32_S10_V4_Apm.CSV")), delimiter =";")
A32_S10_V4_Apo = genfromtxt((conv(x) for x in open("Aufgabe 1/CVS/A32_S10_V4_Apo.CSV")), delimiter =";")
print(A05_S10_V4_Aphoch)
# Out:
# [[3.999932e+02 1.125225e+00]
#  [4.000535e+02 1.024400e+00]
#  [4.001138e+02 9.143244e-01]
#  ...
#  [3.999872e+03 6.516430e+00]
#  [3.999932e+03 6.516371e+00]
#  [3.999992e+03 6.516585e+00]]

# %%
#Apertur änderungen
plt.figure(figsize = [7,3])
plt.subplot(111)
plt.plot(A05_S10_V4_Aphoch[:,0],A05_S10_V4_Aphoch[:,1],label="Apertur: hoch")
plt.plot(A05_S10_V4_Apm[:,0],A05_S10_V4_Apm[:,1],label="Apertur: mittel")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")

plt.savefig("plots/ap_hoch.pdf")
plt.subplot(111)
plt.figure(figsize = [7,3])
plt.xlim((925,960))
plt.ylim((8,12))
plt.legend(['Apertur: hoch', 'Apertur: mitte'])
plt.subplot(111)
plt.plot(A05_S10_V4_Aphoch[:,0],A05_S10_V4_Aphoch[:,1],label="Apertur: hoch")
plt.plot(A05_S10_V4_Apm[:,0],A05_S10_V4_Apm[:,1],label="Apertur: mittel")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/ap_hoch_zoom.pdf")

# %%
#Schritt änderungen
plt.figure(figsize = [7,3])
plt.subplot(111)
plt.plot(A4_S1_V4_Apm[:,0],A4_S1_V4_Apm[:,1],label="Anzahl der Schritt: 1")
plt.plot(A4_S10_V4_Apm[:,0],A4_S10_V4_Apm[:,1],label="Anzahl der Schritt: 50")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/Schrit 1.pdf")


plt.subplot(111)
plt.figure(figsize = [7,3])
plt.xlim((3600,3800))
plt.ylim((15,50))
plt.legend(['Apertur: hoch', 'Apertur: mitte'])
plt.subplot(111)
plt.plot(A4_S1_V4_Apm[:,0],A4_S1_V4_Apm[:,1],label="Anzahl der Schritt: 1")
plt.plot(A4_S10_V4_Apm[:,0],A4_S10_V4_Apm[:,1],label="Anzahl der Schritt: 50")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/Schrit 50 Zoom.pdf")
#plot

# %%
#Schritt änderungen
plt.figure(figsize = [7,3])
plt.plot(A4_S10_V4_Apm_Boxcar[:,0],A4_S10_V4_Apm_Boxcar[:,1],label="Grenzen:'Boxcar'")
plt.plot(A4_S10_V4_Apm_cosine[:,0],A4_S10_V4_Apm_cosine[:,1],label="Grenzen:'Cosin'")
plt.plot(A4_S10_V4_Apm_dreieck[:,0],A4_S10_V4_Apm_dreieck[:,1],label="Anzahl der Schritt: 50")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/grenzen.pdf")



plt.figure(figsize = [7,3])
plt.xlim((3620,3640))
plt.ylim((15,50))
plt.plot(A4_S10_V4_Apm_Boxcar[:,0],A4_S10_V4_Apm_Boxcar[:,1],label="Grenzen:'Boxcar' ")
plt.plot(A4_S10_V4_Apm_cosine[:,0],A4_S10_V4_Apm_cosine[:,1],label="Grenzen: 'Cosine'")
plt.plot(A4_S10_V4_Apm_dreieck[:,0],A4_S10_V4_Apm_dreieck[:,1],label="Grenzen: 'Dreieck'")
plt.legend(loc = "best")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/grenzen zoom.pdf")


plt.figure(figsize = [7,3])
plt.xlim((3500,4000))
plt.ylim((15,50))
plt.plot(A4_S10_V4_Apm_Boxcar[:,0],A4_S10_V4_Apm_Boxcar[:,1],label="Grenzen:'Boxcar' ")
plt.plot(A4_S10_V4_Apm_cosine[:,0],A4_S10_V4_Apm_cosine[:,1],label="Grenzen: 'Cosine'")
plt.plot(A4_S10_V4_Apm_dreieck[:,0],A4_S10_V4_Apm_dreieck[:,1],label="Grenzen: 'Dreieck'")
plt.legend(loc = "best")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/grenzen zoom rand.pdf")

# %%
#Schritt änderungen
plt.figure(figsize = [7,3])
plt.plot(A4_S10_V4_Apm[:,0],A4_S10_V4_Apm[:,1],label="Blende: offen")
plt.plot(A4_S10_V4_Apo[:,0],A4_S10_V4_Apo[:,1],label="Blende: mittel")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/ap0.pdf")



plt.figure(figsize = [7,3])
plt.xlim((3600,3700))
plt.ylim((15,50))
plt.plot(A4_S10_V4_Apm[:,0],A4_S10_V4_Apm[:,1],label="Anzahl der Schritt: mittel")
plt.plot(A4_S10_V4_Apo[:,0],A4_S10_V4_Apo[:,1],label="Anzahl der Schritt: offen")
plt.legend(loc = "best")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/ap0 zoom.pdf")

# %%
#Schritt änderungen
plt.figure(figsize = [7,3])
plt.plot(A4_S10_V32_Apm[:,0],A4_S10_V32_Apm[:,1],label="Schritte: 10 ")
plt.plot(A4_S50_V4_Apm[:,0],A4_S50_V4_Apm[:,1],label="Schritte: 50")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")


plt.savefig("plots/schritte.pdf")

plt.figure(figsize = [7,3])
plt.xlim((3600,3700))
plt.ylim((0,35))
plt.plot(A4_S10_V32_Apm[:,0],A4_S10_V32_Apm[:,1],label="Schritte: 10 ")
plt.plot(A4_S50_V4_Apm[:,0],A4_S50_V4_Apm[:,1],label="Schritte: 50")
plt.legend(loc = "best")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/schritte_zoom.pdf")

# %%
#Schritt änderungen
plt.figure(figsize = [7,3])
plt.plot(A32_S10_V4_Apm[:,0],A32_S10_V4_Apm[:,1],label="Auflösung:32, Apertur: niedrig ")
plt.plot(A32_S10_V4_Apo[:,0],A32_S10_V4_Apo[:,1],label="Auflösung:32, Apertur:offen ")
plt.legend(loc = "upper right")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/A32.pdf")



plt.figure(figsize = [7,3])
plt.xlim((2500,3000))
plt.ylim((0,70))
plt.plot(A32_S10_V4_Apm[:,0],A32_S10_V4_Apm[:,1],label="Auflösung:32, Apertur: niedrig ")
plt.plot(A32_S10_V4_Apo[:,0],A32_S10_V4_Apo[:,1],label="Auflösung:32, Apertur:offen ")
plt.legend(loc = "best")
plt.ylabel("Intensität")
plt.xlabel(r"Wellenvektor k$[\mathrm{cm}^{-1}]$")
plt.savefig("plots/A32 zoom.pdf")
